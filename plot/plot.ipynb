# %% [markdown]
# #### Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot très simple

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# #### x et y

# %%
plt.plot([1,2,3,4], [4,6,2,1]) # l'axe horizontal en premier et le vertical en second

# %% [markdown]
# On peut faire rentrer des listes, des tupple, des array numpy, ou des séries pandas.
# On peut aussi y faire rentrer des matrices ou des dataframes.

# %%
import numpy as np
plt.plot(np.array([[1,2,3,5],
                   [4,5,6,8],
                  [12,18,22,30]]))

# %% [markdown]
# #### Compléter un plot matplotlib

# %%
plt.figure(figsize=(12,6))

plt.plot([1,2,3,4], [4,6,2,1], label = "coucou", marker = "o")
plt.plot([1,2,3,4], [1,3,4,7], label = "hello", marker = "x", linestyle = "dashed")
plt.plot([1,2,3,4], [3,4,5,6], label = "green", marker = "x", linestyle = "--", color="green")
plt.plot([1,2,3,4], [6,5,4,3], label = "hello", marker = "x", linestyle = "-.", color="green", linewidth=7)


plt.xlabel("l'axe des x")
plt.ylabel("l'axe des y")


plt.title("Un exemple de graph")
plt.legend(loc=3) # Pour faire apparaitre le label de chaque ligne
plt.grid()

# %% [markdown]
# Issu du [matplotlib Usage Guide](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py)

# %% [markdown]
# ![image.png](anatomy_of_plotly_figure.png)

# %%
from matplotlib.ticker import MultipleLocator

plt.figure(figsize=(12,6))

ml = MultipleLocator(1)


plt.plot([1,2,3,4], [4,6,2,1], label = "coucou", marker = "o")
plt.plot([1,2,3,4], [1,3,4,7], label = "hello", marker = "x", linestyle = "dashed")
plt.plot([1,2,3,4], [3,4,5,6], label = "green", marker = "x", linestyle = "--", color="green")
plt.plot([1,2,3,4], [6,5,4,3], label = "hello", marker = "x", linestyle = "-.", color="green", linewidth=7)


plt.xlabel("l'axe des x")
plt.ylabel("l'axe des y")



plt.title("Un exemple de graph")
plt.legend(loc=3) # Pour faire apparaitre le label de chaque ligne
plt.grid()
plt.axes().xaxis.set_minor_locator(ml)

# %% [markdown]
# #### Graphs les plus courrants

# %%
#Histogramme
plt.hist([1,1,1,2,2,3,3,3,3,4])
# Out:
# (array([3., 0., 0., 2., 0., 0., 4., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.random.normal(0,1, 10000), bins=30, range=(-2,2));

# %%
plt.hist(np.random.normal(0,1, 10000), bins=30, range=(-2,2), alpha=.4)
plt.hist(np.random.normal(0.3,.5, 7000), bins=30, range=(-2,2), alpha=.3);

# %%
### Barchart

plt.bar(["chat", "chien","cochon", "canard"], [1,2,3,4])
# Out:
# <BarContainer object of 4 artists>

# %%
### Barchart horizontal (bien si les noms sont longs)

plt.barh(["chat", "chien","cochon", "canard"], [1,2,3,4])
# Out:
# <BarContainer object of 4 artists>

# %%
#### Scatter plot

# %%
plt.scatter([1,2,3,4], [4,6,2,1])

# %% [markdown]
# #### Plusieurs plots (subplots)

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))

# %%
axs[0].barh(["chat", "chien","cochon", "canard"], [1,2,3,4])
axs[0].set_title("Subplot no 1")


axs[1].plot([1,2,3,4], [4,6,2,1], label = "coucou", marker = "o")
axs[1].plot([1,2,3,4], [1,3,4,7], label = "hello", marker = "x", linestyle = "dashed")

axs[1].set_title("Subplot no 2")

f

# %%
f, axs = plt.subplots(2, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
axs[0,0].plot([1,2,3,4])
axs[0,0].plot([2,2,2,2])
axs[1,0].plot([2,2,2,3], color="c")
axs[1,1].plot([3,2,2,3], color = "green")
axs[0,1].plot([3,3,2,3], color = "k")

# %% [markdown]
# ### Seaborn un matplotlib plus facile orienté sur la visualisation statistique
#
# (ressource : Seaborn overview : https://seaborn.pydata.org/tutorial/function_overview.html )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(data= ([1,2,3,4], [4,6,2,1]))
# Out:
# <AxesSubplot:>

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Seaborn est juste une surcourche à matplotlib")
# Out:
# Text(0.5, 1.0, 'Seaborn est juste une surcourche à matplotlib')

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
g = sns.relplot(data=tips, x="total_bill", y="tip")
g.ax.axline(xy1=(10, 2), slope=.2, color="b", dashes=(5, 2))

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(data=penguins, hue="species")

# %%
pd.plotting.scatter_matrix(penguins, figsize=(14,10));

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(x="total_bill", y="tip", col="sex", hue="sex", data=tips,
                logistic=False, truncate=False)

# %% [markdown]
# Il existe plein de type de plot faisable avec matplotlib ou/et seaborn. Il est interessant d'aller voir les galleries et la documentation.

# %% [markdown]
# Exemple galery :
# - Seaborn : https://seaborn.pydata.org/examples/index.html
# - Matplotlib : https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# ### Utiliser directement pandas pour faire des plots

# %% [markdown]
# Documentation pandas pour faire des plots : https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
tips.plot.scatter("total_bill", "tip")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.sex.value_counts(normalize=True).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
tips.sex.value_counts(normalize=True).plot(kind="barh", figsize=(2,4))
plt.title("Un plot généré avec pandas")
# Out:
# Text(0.5, 1.0, 'Un plot généré avec pandas')

# %%
tips.total_bill.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plotly

# %% [markdown]
# Plotly est une librairie qui permet de faire des plot interactif ( et des dashboards avec dash). Son pendant chez Anaconda s'appelle Bokeh (et holoview pour les dashboards).
# Altair est une autre librairie interactive.
#
#
# Plotly permet généralement de réaliser des plots plus simplement qu'avec Bokeh, mais Bokeh intègre des formes d'interactions (de type slider, etc) sans avoir à passer par holoview (alors que dash est nécessaire pour plotly).

# %% [markdown]
# TODO: procédure d'installation pour fonctionnement avec jupyter.
# ```
# pip install plotly
# pip install ipywidgets
# conda install -c conda-forge/label/cf202003 nodejs --yes
# jupyter labextension install jupyterlab-plotly
# jupyter labextension install @jupyter-widgets/jupyterlab-manager plotlywidget
# ```

# %% [markdown]
# ! pip install plotly
# ! pip install ipywidgets
# ! conda install -c conda-forge/label/cf202003 nodejs --yes
# ! jupyter labextension install jupyterlab-plotly
# ! jupyter labextension install @jupyter-widgets/jupyterlab-manager plotlywidget

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", title="A Plotly Express Figure")

# If you print the figure, you'll see that it's just a regular figure with data and layout
# print(fig)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e2305caa8941> in <module>
# ----> 1 import plotly.express as px
#       2
#       3 df = px.data.iris()
#       4 fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", title="A Plotly Express Figure")
#       5
#
# ModuleNotFoundError: No module named 'plotly'

# %%
fig.write_html("test_plotly.html")

# %% [markdown]
# Un exemple avec dash : https://dash-gallery.plotly.host/dash-svm/

# %% [markdown]
# ### Utiliser plotly en backend pour pandas

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"

df = pd.DataFrame(dict(a=[1,3,2], b=[3,2,1]))
fig = df.plot()
fig.show()

# %%
tips.sex.value_counts(normalize=True).plot(kind="bar")

# %%
tips.plot.scatter("total_bill", "tip",  color="sex")

# %% [markdown]
# Easy plotly : https://github.com/mwouts/easyplotly

# %% [markdown]
# Bokeh gallery : https://docs.bokeh.org/en/latest/docs/gallery.html

# %%
### Altair


import altair as alt
from vega_datasets import data

source = data.wheat()

alt.Chart(source).mark_bar().encode(
    x='year:O',
    y="wheat:Q",
    # The highlight will be set on the result of a conditional statement
    color=alt.condition(
        alt.datum.year == 1810,  # If the year is 1810 this test returns True,
        alt.value('orange'),     # which sets the bar orange.
        alt.value('steelblue')   # And if it's not true it sets the bar steelblue.
    )
).properties(width=600)
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

# Configure the options common to all layers
brush = alt.selection(type='interval')
base = alt.Chart(source).add_selection(brush)

# Configure the points
points = base.mark_point().encode(
    x=alt.X('Miles_per_Gallon', title=''),
    y=alt.Y('Horsepower', title=''),
    color=alt.condition(brush, 'Origin', alt.value('grey'))
)

# Configure the ticks
tick_axis = alt.Axis(labels=False, domain=False, ticks=False)

x_ticks = base.mark_tick().encode(
    alt.X('Miles_per_Gallon', axis=tick_axis),
    alt.Y('Origin', title='', axis=tick_axis),
    color=alt.condition(brush, 'Origin', alt.value('lightgrey'))
)

y_ticks = base.mark_tick().encode(
    alt.X('Origin', title='', axis=tick_axis),
    alt.Y('Horsepower', axis=tick_axis),
    color=alt.condition(brush, 'Origin', alt.value('lightgrey'))
)

# Build the chart
y_ticks | (points & x_ticks)
# Out:
# alt.HConcatChart(...)

# %%
print("hello")
# Out:
# hello
